# %%
import findspark 
findspark.init()
import pyspark
findspark.find()
# Out:
# 'C:\\spark\\spark-3.2.0-bin-hadoop3.2'

# %%
from pyspark import SparkConf,SparkContext
from pyspark.sql import SparkSession

conf = pyspark.SparkConf().setAppName('MyApp').setMaster('local')
sc = pyspark.SparkContext(conf=conf)
spark = SparkSession(sc)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://LAPTOP-15HARP1G:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>MyApp</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
trans_data = spark.read.csv('D:/Code_Place/Data-Science/Scikit Learn/trasport/ts_transport_fitness_01_03_2022to31_03_2022.csv', inferSchema=True, header=True)
trans_data.printSchema()
# Out:
# root
#  |-- slno: integer (nullable = true)
#  |-- registrationNo: string (nullable = true)
#  |-- vehicleClass: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- validFrom: string (nullable = true)
#  |-- validTo: string (nullable = true)
#  |-- transactiontType: string (nullable = true)
#  |-- OfficeCd: string (nullable = true)
#  |-- fromdate: string (nullable = true)
#  |-- todate: string (nullable = true)

# %%
trans_data.count()
# Out:
# 76657

# %%
trans_data.head(5)
# Out:
# [Row(slno=770352, registrationNo='TS07UC8621', vehicleClass='Goods Carriage', status='APPROVED', validFrom='02/03/2022', validTo='01/03/2023', transactiontType='Renewal', OfficeCd='RTA ADILABAD', fromdate='01/03/2022', todate='02/03/2022'),
#  Row(slno=500609, registrationNo='TS01UC2799', vehicleClass='Goods Carriage', status='APPROVED', validFrom='02/03/2022', validTo='01/03/2024', transactiontType='Renewal', OfficeCd='RTA ADILABAD', fromdate='01/03/2022', todate='02/03/2022'),
#  Row(slno=530243, registrationNo='TS01UA7497', vehicleClass='Goods Carriage', status='APPROVED', validFrom='02/03/2022', validTo='01/03/2024', transactiontType='Renewal', OfficeCd='RTA ADILABAD', fromdate='01/03/2022', todate='02/03/2022'),
#  Row(slno=16716, registrationNo='AP01V3757', vehicleClass='Trailer For Commercial Use', status='APPROVED', validFrom='02/03/2022', validTo='01/03/2023', transactiontType='Renewal', OfficeCd='RTA ADILABAD', fromdate='01/03/2022', todate='02/03/2022'),
#  Row(slno=34122, registrationNo='AP01W8405', vehicleClass='Goods Carriage', status='APPROVED', validFrom='02/03/2022', validTo='01/03/2023', transactiontType='Renewal', OfficeCd='RTA ADILABAD', fromdate='01/03/2022', todate='02/03/2022')]

# %%
from pyspark.sql.functions import col, skewness, kurtosis
trans_data.select(skewness('_c0'),kurtosis('_c0')).show()
# Out:
# +-------------------+-------------------+
# |      skewness(_c0)|      kurtosis(_c0)|
# +-------------------+-------------------+
# |-0.3511757043707716|-1.0309084999246485|
# +-------------------+-------------------+

# %%
trans_data.describe().show()
# Out:
# +-------+------------------+--------------+--------------------+--------+----------+----------+----------------+-----------------+----------+----------+
# |summary|              slno|registrationNo|        vehicleClass|  status| validFrom|   validTo|transactiontType|         OfficeCd|  fromdate|    todate|
# +-------+------------------+--------------+--------------------+--------+----------+----------+----------------+-----------------+----------+----------+
# |  count|             76657|         76657|               76657|   76657|     76657|     76657|           76657|            76657|     76657|     76657|
# |   mean| 713451.5525000979|          null|                null|    null|      null|      null|            null|             null|      null|      null|
# | stddev|361718.45413726586|          null|                null|    null|      null|      null|            null|             null|      null|      null|
# |    min|                90|       AAI3151|           Ambulance|APPROVED|01/02/2022|01/01/2024|      Data Entry|     RTA ADILABAD|01/03/2022|02/03/2022|
# |    max|           1267551|    ap39tf9333|Trailer For Comme...|APPROVED|31/12/2021|31/08/2023|         Renewal|UNIT OFFICE PARGI|30/03/2022|31/03/2022|
# +-------+------------------+--------------+--------------------+--------+----------+----------+----------------+-----------------+----------+----------+

# %%
df_main = trans_data.toPandas()
df_main.head()
# Out:
#      slno registrationNo                vehicleClass    status   validFrom  \
# 0  770352     TS07UC8621              Goods Carriage  APPROVED  02/03/2022
# 1  500609     TS01UC2799              Goods Carriage  APPROVED  02/03/2022
# 2  530243     TS01UA7497              Goods Carriage  APPROVED  02/03/2022
# 3   16716      AP01V3757  Trailer For Commercial Use  APPROVED  02/03/2022
# 4   34122      AP01W8405              Goods Carriage  APPROVED  02/03/2022
#
#       validTo transactiontType      OfficeCd    fromdate      todate
# 0  01/03/2023          Renewal  RTA ADILABAD  01/03/2022  02/03/2022
# 1  01/03/2024          Renewal  RTA ADILABAD  01/03/2022  02/03/2022
# 2  01/03/2024          Renewal  RTA ADILABAD  01/03/2022  02/03/2022
# 3  01/03/2023          Renewal  RTA ADILABAD  01/03/2022  02/03/2022
# 4  01/03/2023          Renewal  RTA ADILABAD  01/03/2022  02/03/2022

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2.7.0

# %%
df = df_main.copy()
col_list = df.columns
print(col_list)
# Out:
# Index(['slno', 'registrationNo', 'vehicleClass', 'status', 'validFrom',
#        'validTo', 'transactiontType', 'OfficeCd', 'fromdate', 'todate'],
#       dtype='object')

# %%
df.replace(np.nan,0)
# Out:
#          slno registrationNo                vehicleClass    status  \
# 0      770352     TS07UC8621              Goods Carriage  APPROVED
# 1      500609     TS01UC2799              Goods Carriage  APPROVED
# 2      530243     TS01UA7497              Goods Carriage  APPROVED
# 3       16716      AP01V3757  Trailer For Commercial Use  APPROVED
# 4       34122      AP01W8405              Goods Carriage  APPROVED
# ...       ...            ...                         ...       ...
# 76652   65180      AP10U5158              Goods Carriage  APPROVED
# 76653   66091      AP11T3969              Goods Carriage  APPROVED
# 76654   69196      AP10V5554              Goods Carriage  APPROVED
# 76655   66901      AP09U5575              Goods Carriage  APPROVED
# 76656   20923     AP03TC1964              Goods Carriage  APPROVED
#
#         validFrom     validTo transactiontType      OfficeCd    fromdate  \
# 0      02/03/2022  01/03/2023          Renewal  RTA ADILABAD  01/03/2022
# 1      02/03/2022  01/03/2024          Renewal  RTA ADILABAD  01/03/2022
# 2      02/03/2022  01/03/2024          Renewal  RTA ADILABAD  01/03/2022
# 3      02/03/2022  01/03/2023          Renewal  RTA ADILABAD  01/03/2022
# 4      02/03/2022  01/03/2023          Renewal  RTA ADILABAD  01/03/2022
# ...           ...         ...              ...           ...         ...
# 76652  30/03/2022  29/03/2023          Renewal     RTA UPPAL  30/03/2022
# 76653  31/03/2022  30/03/2023          Renewal     RTA UPPAL  30/03/2022
# 76654  30/03/2022  29/03/2023          Renewal     RTA UPPAL  30/03/2022
# 76655  30/03/2022  29/03/2023          Renewal     RTA UPPAL  30/03/2022
# 76656  30/03/2022  29/03/2023          Renewal     RTA UPPAL  30/03/2022
#
#            todate
# 0      02/03/2022
# 1      02/03/2022
# 2      02/03/2022
# 3      02/03/2022
# 4      02/03/2022
# ...           ...
# 76652  31/03/2022
# 76653  31/03/2022
# 76654  31/03/2022
# 76655  31/03/2022
# 76656  31/03/2022
#
# [76657 rows x 10 columns]

# %%
df.dtypes
# Out:
# slno                 int32
# registrationNo      object
# vehicleClass        object
# status              object
# validFrom           object
# validTo             object
# transactiontType    object
# OfficeCd            object
# fromdate            object
# todate              object
# dtype: object

# %%
df['registrationNo']
# Out:
# 0        TS07UC8621
# 1        TS01UC2799
# 2        TS01UA7497
# 3         AP01V3757
# 4         AP01W8405
#             ...
# 76652     AP10U5158
# 76653     AP11T3969
# 76654     AP10V5554
# 76655     AP09U5575
# 76656    AP03TC1964
# Name: registrationNo, Length: 76657, dtype: object

# %%
df['status'] = pd.Categorical(df['status'])
df['status'] = df.status.cat.codes
df['vehicleClass'] = pd.Categorical(df['vehicleClass'])
df['vehicleClass'] = df.vehicleClass.cat.codes
df['registrationNo'] = pd.Categorical(df['registrationNo'])
df['registrationNo'] = df.registrationNo.cat.codes
df['transactiontType'] = pd.Categorical(df['transactiontType'])
df['transactiontType'] = df.transactiontType.cat.codes
df['OfficeCd'] = pd.Categorical(df['OfficeCd'])
df['OfficeCd'] = df.OfficeCd.cat.codes
df['validFrom'] = pd.Categorical(df['validFrom'])
df['validFrom'] = df.validFrom.cat.codes
df['validTo'] = pd.Categorical(df['validTo'])
df['validTo'] = df.validTo.cat.codes

df.head()
# Out:
#      slno  registrationNo  vehicleClass  status  validFrom  validTo  \
# 0  770352           18563            12       0         10        2
# 1  500609           13019            12       0         10        3
# 2  530243           12715            12       0         10        3
# 3   16716             151            27       0         10        2
# 4   34122             257            12       0         10        2
#
#    transactiontType  OfficeCd    fromdate      todate
# 0                 4         0  01/03/2022  02/03/2022
# 1                 4         0  01/03/2022  02/03/2022
# 2                 4         0  01/03/2022  02/03/2022
# 3                 4         0  01/03/2022  02/03/2022
# 4                 4         0  01/03/2022  02/03/2022

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# sns.set(style="darkgrid")
# trans_data = sns.load_dataset("iris")

sns.histplot(data=df, x="slno", bins=20)
plt.show()

# %%
# # sns.heatmap(trans_data.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# sns.countplot(data=trans_data)
clist = ['slno', 'registrationNo', 'status']
df_hist = df[clist]
df_hist.hist(bins=50, figsize=(15,10))
# Out:
# array([[<AxesSubplot:title={'center':'slno'}>,
#         <AxesSubplot:title={'center':'registrationNo'}>],
#        [<AxesSubplot:title={'center':'status'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
numaric_call = ['slno', 'registrationNo', 'vehicleClass', 'status', 'validFrom',
       'validTo', 'transactiontType', 'OfficeCd']
data = df[numaric_call]
data.head()
# Out:
#      slno  registrationNo  vehicleClass  status  validFrom  validTo  \
# 0  770352           18563            12       0         10        2
# 1  500609           13019            12       0         10        3
# 2  530243           12715            12       0         10        3
# 3   16716             151            27       0         10        2
# 4   34122             257            12       0         10        2
#
#    transactiontType  OfficeCd
# 0                 4         0
# 1                 4         0
# 2                 4         0
# 3                 4         0
# 4                 4         0

# %%
sns.pairplot(data=data)

# %%
dataset = data.copy()
dataset.isna().sum()
# Out:
# slno                0
# registrationNo      0
# vehicleClass        0
# status              0
# validFrom           0
# validTo             0
# transactiontType    0
# OfficeCd            0
# dtype: int64

# %%
sns.distplot(dataset['validTo'])
# Out:
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='validTo', ylabel='Density'>

# %%
dataset.corr()
# Out:
#                       slno  registrationNo  vehicleClass  status  validFrom  \
# slno              1.000000        0.960921      0.149757     NaN  -0.035174
# registrationNo    0.960921        1.000000      0.109688     NaN  -0.030956
# vehicleClass      0.149757        0.109688      1.000000     NaN  -0.023997
# status                 NaN             NaN           NaN     NaN        NaN
# validFrom        -0.035174       -0.030956     -0.023997     NaN   1.000000
# validTo          -0.032010       -0.027831     -0.023269     NaN   0.996735
# transactiontType -0.355003       -0.335368     -0.226989     NaN  -0.045825
# OfficeCd          0.060456        0.115838     -0.214455     NaN   0.016678
#
#                    validTo  transactiontType  OfficeCd
# slno             -0.032010         -0.355003  0.060456
# registrationNo   -0.027831         -0.335368  0.115838
# vehicleClass     -0.023269         -0.226989 -0.214455
# status                 NaN               NaN       NaN
# validFrom         0.996735         -0.045825  0.016678
# validTo           1.000000         -0.046972  0.016271
# transactiontType -0.046972          1.000000  0.023923
# OfficeCd          0.016271          0.023923  1.000000

# %%
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data.columns
# Out:
# Index(['slno', 'registrationNo', 'vehicleClass', 'status', 'validFrom',
#        'validTo', 'transactiontType', 'OfficeCd'],
#       dtype='object')

# %%
X= data[['slno', 'registrationNo', 'vehicleClass', 'validFrom',
       'validTo', 'transactiontType', 'OfficeCd']]
y = data['status']

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=0)

X_train.shape, X_test.shape
# Out:
# ((53659, 7), (22998, 7))

# %%
from sklearn.feature_selection import VarianceThreshold
var_thres=VarianceThreshold(threshold=0)
var_thres.fit(X_train)
# Out:
# VarianceThreshold(threshold=0)

# %%
print("Find Constant and Non-Constant Features:\n",var_thres.get_support())
print("No. of Non-Constant Features: ",len(X_train.columns[var_thres.get_support()]))
# Out:
# Find Constant and Non-Constant Features:
#  [ True  True  True  True  True  True  True]
# No. of Non-Constant Features:  7

# %%
constant_columns = [column for column in X_train.columns
                    if column not in X_train.columns[var_thres.get_support()]]

print(len(constant_columns))

for column in constant_columns:
    print(column)
# Out:
# 0

# %%
X_train=X_train.drop(constant_columns,axis=1)
X_test=X_test.drop(constant_columns,axis=1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
# with the following function we can select highly correlated features
# it will remove the first feature that is correlated with anything other feature

def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

# %%
corr_features = correlation(X_train, 0.7)
print("No. of Correlation Features:",len(set(corr_features)))
corr_features
# Out:
# No. of Correlation Features: 2
# {'registrationNo', 'validTo'}

# %%
X_train=X_train.drop(corr_features,axis=1)
X_test=X_test.drop(corr_features,axis=1)

# %%
from sklearn import preprocessing
from sklearn import utils
print(utils.multiclass.type_of_target(y_train))
# Out:
# binary

# %%
utils.multiclass.type_of_target(X_train.astype('int'))
utils.multiclass.type_of_target(y_train.astype('int'))
# Out:
# 'binary'

# %%
mp=10
X_train.head(2)
# Out:
#           slno  vehicleClass  validFrom  transactiontType  OfficeCd
# 64242  1087605            20        250                 2        21
# 76524    59130            12        280                 4        28

# %%
# checking distributions of all features
fig, axs = plt.subplots(ncols=6,nrows=3,figsize=(20,10))
index = 0
axs = axs.flatten()
for k,v in X.items():
    sns.distplot(v, ax=axs[index])
    index+=1

fig.delaxes(axs[index]) # deleting the 18th figure
plt.tight_layout(pad=0.3, w_pad=0.2,h_pad = 4.5)
# Out:
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\python\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
from sklearn.metrics import plot_confusion_matrix # will plot the confusion matrix
import time
model_performance = pd.DataFrame(columns=['Accuracy','Recall','Precision','F1-Score','time to train','time to predict','total time'])

# %%
### KNeighbors

# %%
#%%time
from sklearn.neighbors import KNeighborsClassifier
start = time.time()
model = KNeighborsClassifier(n_neighbors=3).fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, classification_report, confusion_matrix,accuracy_score
accuracy = accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['kNN'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 100.00%
# Recall: 100.00%
# Precision: 100.00%
# F1-Score: 100.00%
# time to train: 0.20 s
# time to predict: 1.36 s
# total: 1.56 s

# %%
plt.rcParams['figure.figsize']=5,5 
sns.set_style("white")
plot_confusion_matrix(model, X_test, y_test, cmap=plt.cm.Blues)  
plt.show()

# %%
### RandomForest

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
start = time.time()
model = RandomForestClassifier(n_estimators = 100,n_jobs=-1,random_state=0,bootstrap=True,).fit(X_train,y_train)
end_train = time.time()
y_predictions = model.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()
# Out:
# Wall time: 1.16 s

# %%
accuracy =accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Random Forest'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 100.00%
# Recall: 100.00%
# Precision: 100.00%
# F1-Score: 100.00%
# time to train: 0.68 s
# time to predict: 0.15 s
# total: 0.83 s

# %%
plt.rcParams['figure.figsize']=5,5 
sns.set_style("white")
plot_confusion_matrix(model, X_test, y_test, cmap=plt.cm.Blues)  
plt.show()

# %%
print('Report:\n',classification_report(y_test, y_predictions))
# Out:
# Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     22998
#
#     accuracy                           1.00     22998
#    macro avg       1.00      1.00      1.00     22998
# weighted avg       1.00      1.00      1.00     22998

# %% [markdown]
# ### DecisionTree

# %%
# %%time
from sklearn.tree import DecisionTreeClassifier
start = time.time()
model3 = DecisionTreeClassifier(criterion='gini', max_depth=4, random_state=0).fit(X_train,y_train)
end_train = time.time()
y_predictions = model3.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()
# Out:
# Wall time: 15.8 ms

# %%
accuracy =accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Decision Tree'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 100.00%
# Recall: 100.00%
# Precision: 100.00%
# F1-Score: 100.00%
# time to train: 0.01 s
# time to predict: 0.00 s
# total: 0.02 s

# %%
plt.rcParams['figure.figsize']=5,5 
sns.set_style("white")
plot_confusion_matrix(model3, X_test, y_test, cmap=plt.cm.Blues)  
plt.show()

# %%
### Navie Bayes

# %%
#%%time
from sklearn.naive_bayes import MultinomialNB
start = time.time()
model4 = MultinomialNB().fit(X_train,y_train)
end_train = time.time()
y_predictions = model4.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()
# Out:
# c:\python\lib\site-packages\sklearn\naive_bayes.py:780: RuntimeWarning: invalid value encountered in log
#   self.feature_log_prob_ = (np.log(smoothed_fc) -
# c:\python\lib\site-packages\sklearn\naive_bayes.py:781: RuntimeWarning: invalid value encountered in log
#   np.log(smoothed_cc.reshape(-1, 1)))

# %%
accuracy =accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Naive Bayes'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 100.00%
# Recall: 100.00%
# Precision: 100.00%
# F1-Score: 100.00%
# time to train: 0.01 s
# time to predict: 0.01 s
# total: 0.02 s

# %%
plt.rcParams['figure.figsize']=5,5 
sns.set_style("white")
plot_confusion_matrix(model4, X_test, y_test, cmap=plt.cm.Blues)  
plt.show()

# %%
### AdaBoostClassifier

# %%
# %%time
from sklearn.ensemble import AdaBoostClassifier
start = time.time()
model5 = AdaBoostClassifier(n_estimators=100, learning_rate=1, random_state=0).fit(X_train,y_train)
end_train = time.time()
y_predictions = model5.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()
# Out:
# Wall time: 14.3 ms

# %%
accuracy =accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['AdaBoost'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 100.00%
# Recall: 100.00%
# Precision: 100.00%
# F1-Score: 100.00%
# time to train: 0.01 s
# time to predict: 0.00 s
# total: 0.01 s

# %%
plt.rcParams['figure.figsize']=5,5 
sns.set_style("white")
plot_confusion_matrix(model5, X_test, y_test, cmap=plt.cm.Blues)  
plt.show()

# %%
### CAT Boost

# %%
# %%time
from xgboost import XGBClassifier
start = time.time()
model6 =  XGBClassifier(n_estimators=100, learning_rate=1.0, random_state=0).fit(X_train,y_train)
end_train = time.time()
y_predictions = model6.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()
# Out:
# Wall time: 1.06 s

# %%
accuracy =accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['XG Boost'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 100.00%
# Recall: 100.00%
# Precision: 100.00%
# F1-Score: 100.00%
# time to train: 0.92 s
# time to predict: 0.01 s
# total: 0.93 s

# %%
plt.rcParams['figure.figsize']=5,5 
sns.set_style("white")
plot_confusion_matrix(model6, X_test, y_test, cmap=plt.cm.Blues)  
plt.show()

# %%
### GradientBoost

# %%
# %%time
from catboost import CatBoostClassifier
start = time.time()
model7 = CatBoostClassifier(iterations=100).fit(X_train,y_train)
end_train = time.time()
y_predictions = model7.predict(X_test) # These are the predictions from the test data.
end_predict = time.time()
# Out:
# Wall time: 0 ns

# %%
accuracy =accuracy_score(y_test, y_predictions)
recall = recall_score(y_test, y_predictions, average='weighted')
precision = precision_score(y_test, y_predictions, average='weighted')
f1s = f1_score(y_test, y_predictions, average='weighted')

print("Accuracy: "+ "{:.2%}".format(accuracy))
print("Recall: "+ "{:.2%}".format(recall))
print("Precision: "+ "{:.2%}".format(precision))
print("F1-Score: "+ "{:.2%}".format(f1s))
print("time to train: "+ "{:.2f}".format(end_train-start)+" s")
print("time to predict: "+"{:.2f}".format(end_predict-end_train)+" s")
print("total: "+"{:.2f}".format(end_predict-start)+" s")
model_performance.loc['Cat Boost'] = [accuracy, recall, precision, f1s,end_train-start,end_predict-end_train,end_predict-start]
# Out:
# Accuracy: 100.00%
# Recall: 100.00%
# Precision: 100.00%
# F1-Score: 100.00%
# time to train: -595.02 s
# time to predict: 0.01 s
# total: -595.01 s

# %%
plt.rcParams['figure.figsize']=5,5 
sns.set_style("white")
plot_confusion_matrix(model7, X_test, y_test, cmap=plt.cm.Blues)  
plt.show()

# %%
### ExtraTree

# %%
from sklearn.feature_selection import mutual_info_classif
model_performance.fillna(.90,inplace=True)
model_performance.style.background_gradient(cmap='coolwarm').format({'Accuracy': '{:.2%}',
                                                                     'Precision': '{:.2%}',
                                                                     'Recall': '{:.2%}',
                                                                     'F1-Score': '{:.2%}',
                                                                     'time to train':'{:.1f}',
                                                                     'time to predict':'{:.1f}',
                                                                     'total time':'{:.1f}',
                                                                     })
# Out:
# <style  type="text/css" >
# #T_9adc0_row0_col0,#T_9adc0_row0_col1,#T_9adc0_row0_col2,#T_9adc0_row0_col3,#T_9adc0_row1_col0,#T_9adc0_row1_col1,#T_9adc0_row1_col2,#T_9adc0_row1_col3,#T_9adc0_row2_col0,#T_9adc0_row2_col1,#T_9adc0_row2_col2,#T_9adc0_row2_col3,#T_9adc0_row2_col5,#T_9adc0_row3_col0,#T_9adc0_row3_col1,#T_9adc0_row3_col2,#T_9adc0_row3_col3,#T_9adc0_row3_col5,#T_9adc0_row4_col0,#T_9adc0_row4_col1,#T_9adc0_row4_col2,#T_9adc0_row4_col3,#T_9adc0_row4_col5,#T_9adc0_row5_col0,#T_9adc0_row5_col1,#T_9adc0_row5_col2,#T_9adc0_row5_col3,#T_9adc0_row5_col5,#T_9adc0_row6_col0,#T_9adc0_row6_col1,#T_9adc0_row6_col2,#T_9adc0_row6_col3,#T_9adc0_row6_col4,#T_9adc0_row6_col5,#T_9adc0_row6_col6{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_9adc0_row0_col4,#T_9adc0_row0_col5,#T_9adc0_row0_col6,#T_9adc0_row1_col4,#T_9adc0_row1_col6,#T_9adc0_row2_col4,#T_9adc0_row2_col6,#T_9adc0_row3_col4,#T_9adc0_row3_col6,#T_9adc0_row4_col4,#T_9adc0_row4_col6,#T_9adc0_row5_col4,#T_9adc0_row5_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_9adc0_row1_col5{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }</style><table id="T_9adc0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >Recall</th>        <th class="col_heading level0 col2" >Precision</th>        <th class="col_heading level0 col3" >F1-Score</th>        <th class="col_heading level0 col4" >time to train</th>        <th class="col_heading level0 col5" >time to predict</th>        <th class="col_heading level0 col6" >total time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9adc0_level0_row0" class="row_heading level0 row0" >kNN</th>
#                         <td id="T_9adc0_row0_col0" class="data row0 col0" >100.00%</td>
#                         <td id="T_9adc0_row0_col1" class="data row0 col1" >100.00%</td>
#                         <td id="T_9adc0_row0_col2" class="data row0 col2" >100.00%</td>
#                         <td id="T_9adc0_row0_col3" class="data row0 col3" >100.00%</td>
#                         <td id="T_9adc0_row0_col4" class="data row0 col4" >0.2</td>
#                         <td id="T_9adc0_row0_col5" class="data row0 col5" >1.4</td>
#                         <td id="T_9adc0_row0_col6" class="data row0 col6" >1.6</td>
#             </tr>
#             <tr>
#                         <th id="T_9adc0_level0_row1" class="row_heading level0 row1" >Random Forest</th>
#                         <td id="T_9adc0_row1_col0" class="data row1 col0" >100.00%</td>
#                         <td id="T_9adc0_row1_col1" class="data row1 col1" >100.00%</td>
#                         <td id="T_9adc0_row1_col2" class="data row1 col2" >100.00%</td>
#                         <td id="T_9adc0_row1_col3" class="data row1 col3" >100.00%</td>
#                         <td id="T_9adc0_row1_col4" class="data row1 col4" >0.7</td>
#                         <td id="T_9adc0_row1_col5" class="data row1 col5" >0.1</td>
#                         <td id="T_9adc0_row1_col6" class="data row1 col6" >0.8</td>
#             </tr>
#             <tr>
#                         <th id="T_9adc0_level0_row2" class="row_heading level0 row2" >Decision Tree</th>
#                         <td id="T_9adc0_row2_col0" class="data row2 col0" >100.00%</td>
#                         <td id="T_9adc0_row2_col1" class="data row2 col1" >100.00%</td>
#                         <td id="T_9adc0_row2_col2" class="data row2 col2" >100.00%</td>
#                         <td id="T_9adc0_row2_col3" class="data row2 col3" >100.00%</td>
#                         <td id="T_9adc0_row2_col4" class="data row2 col4" >0.0</td>
#                         <td id="T_9adc0_row2_col5" class="data row2 col5" >0.0</td>
#                         <td id="T_9adc0_row2_col6" class="data row2 col6" >0.0</td>
#             </tr>
#             <tr>
#                         <th id="T_9adc0_level0_row3" class="row_heading level0 row3" >Naive Bayes</th>
#                         <td id="T_9adc0_row3_col0" class="data row3 col0" >100.00%</td>
#                         <td id="T_9adc0_row3_col1" class="data row3 col1" >100.00%</td>
#                         <td id="T_9adc0_row3_col2" class="data row3 col2" >100.00%</td>
#                         <td id="T_9adc0_row3_col3" class="data row3 col3" >100.00%</td>
#                         <td id="T_9adc0_row3_col4" class="data row3 col4" >0.0</td>
#                         <td id="T_9adc0_row3_col5" class="data row3 col5" >0.0</td>
#                         <td id="T_9adc0_row3_col6" class="data row3 col6" >0.0</td>
#             </tr>
#             <tr>
#                         <th id="T_9adc0_level0_row4" class="row_heading level0 row4" >AdaBoost</th>
#                         <td id="T_9adc0_row4_col0" class="data row4 col0" >100.00%</td>
#                         <td id="T_9adc0_row4_col1" class="data row4 col1" >100.00%</td>
#                         <td id="T_9adc0_row4_col2" class="data row4 col2" >100.00%</td>
#                         <td id="T_9adc0_row4_col3" class="data row4 col3" >100.00%</td>
#                         <td id="T_9adc0_row4_col4" class="data row4 col4" >0.0</td>
#                         <td id="T_9adc0_row4_col5" class="data row4 col5" >0.0</td>
#                         <td id="T_9adc0_row4_col6" class="data row4 col6" >0.0</td>
#             </tr>
#             <tr>
#                         <th id="T_9adc0_level0_row5" class="row_heading level0 row5" >XG Boost</th>
#                         <td id="T_9adc0_row5_col0" class="data row5 col0" >100.00%</td>
#                         <td id="T_9adc0_row5_col1" class="data row5 col1" >100.00%</td>
#                         <td id="T_9adc0_row5_col2" class="data row5 col2" >100.00%</td>
#                         <td id="T_9adc0_row5_col3" class="data row5 col3" >100.00%</td>
#                         <td id="T_9adc0_row5_col4" class="data row5 col4" >0.9</td>
#                         <td id="T_9adc0_row5_col5" class="data row5 col5" >0.0</td>
#                         <td id="T_9adc0_row5_col6" class="data row5 col6" >0.9</td>
#             </tr>
#             <tr>
#                         <th id="T_9adc0_level0_row6" class="row_heading level0 row6" >Cat Boost</th>
#                         <td id="T_9adc0_row6_col0" class="data row6 col0" >100.00%</td>
#                         <td id="T_9adc0_row6_col1" class="data row6 col1" >100.00%</td>
#                         <td id="T_9adc0_row6_col2" class="data row6 col2" >100.00%</td>
#                         <td id="T_9adc0_row6_col3" class="data row6 col3" >100.00%</td>
#                         <td id="T_9adc0_row6_col4" class="data row6 col4" >-595.0</td>
#                         <td id="T_9adc0_row6_col5" class="data row6 col5" >0.0</td>
#                         <td id="T_9adc0_row6_col6" class="data row6 col6" >-595.0</td>
#             </tr>
#     </tbody></table>
