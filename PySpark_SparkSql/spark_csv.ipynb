# %%
import pandas as pd
num = 1
for data in  pd.read_csv("employees_202206172332.csv", chunksize = 300 ):
    num = num+1
    name = num +'.csv'
    data.to_csv(name)
# Out:
#     emp_no emp_title_id  birth_date  first_name  last_name gender   hire_date
# 0   473302        s0001  1953-07-25    Hideyuki   Zallocco      M  1990-04-28
# 1   475053        e0002  1954-11-18       Byong  Delgrande      F  1991-09-07
# 2    57444        e0002  1958-01-30       Berry       Babb      F  1992-03-21
# 3   421786        s0001  1957-09-28       Xiong   Verhoeff      M  1987-11-26
# 4   282238        e0003  1952-10-28  Abdelkader    Baumann      F  1991-01-18
# ..     ...          ...         ...         ...        ...    ...         ...
# 95  492191        e0002  1962-04-29       Remco     Vakili      F  1990-08-15
# 96  457800        s0001  1963-09-20   Stabislas    Domenig      M  1986-08-04
# 97  446142        e0003  1961-08-22     Gregory    Zedlitz      F  1993-07-10
# 98  201769        e0004  1961-11-06      Jayesh      Merel      M  1992-09-26
# 99   56049        s0001  1952-07-15   Felicidad    Waymire      F  1988-01-15
#
# [100 rows x 7 columns]
# ...
